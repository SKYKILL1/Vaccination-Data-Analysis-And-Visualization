# %% [markdown]
# # **Vaccination Data Analysis And Visualization**

# %% [markdown]
# ##### **Project Type**    - EDA/Visualization
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary**

# %% [markdown]
# This project involved a comprehensive data analysis pipeline to derive actionable insights from global vaccination data. The process began with cleaning and preparing multiple raw datasets, addressing missing values, and standardizing formats. The refined data was then structured and exported to an SQLite database for efficient storage and management. To enhance performance and enable advanced analytics, the database was migrated to PostgreSQL.
#
# The core of the project was performed in Power BI, where a series of interactive dashboards were developed. These visualizations answered critical public health questions, including vaccination coverage rates, drop-off between doses, disease incidence correlations, and the impact of vaccination campaigns. The dashboards effectively identified disparities, tracked progress towards WHO targets, and highlighted high-priority areas for intervention.
#
# Ultimately, this end-to-end project transformed raw data into clear, visual stories, providing valuable tools for health organizations to optimize vaccine distribution and improve global health outcomes.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Analyze global vaccination data to understand trends in vaccination coverage, disease incidence, and effectiveness. Data will be cleaned, and stored in a SQL database. Power BI will be used to connect to the SQL database and create interactive dashboards that provide insights on vaccination strategies and their impact on disease control.

# %% [markdown]
# # ***Let's Begin !***

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
import sqlite3

# %%
df_coverage = pd.read_excel('./Dataset/coverage-data.xlsx')
df_incident = pd.read_excel('./Dataset/incidence-rate-data.xlsx')
df_reported = pd.read_excel('./Dataset/reported-cases-data.xlsx')
df_vac_intro = pd.read_excel('./Dataset/vaccine-introduction-data.xlsx')
df_vac_sched = pd.read_excel('./Dataset/vaccine-schedule-data.xlsx')

# %%
df_coverage
# Out:
#                                 GROUP CODE                    NAME    YEAR  \
# 0                           COUNTRIES  ABW                   Aruba  2023.0
# 1                           COUNTRIES  ABW                   Aruba  2023.0
# 2                           COUNTRIES  ABW                   Aruba  2023.0
# 3                           COUNTRIES  ABW                   Aruba  2023.0
# 4                           COUNTRIES  ABW                   Aruba  2023.0
# ...                               ...  ...                     ...     ...
# 399854                    WHO_REGIONS  WPR  Western Pacific Region  1980.0
# 399855                    WHO_REGIONS  WPR  Western Pacific Region  1980.0
# 399856                    WHO_REGIONS  WPR  Western Pacific Region  1980.0
# 399857                    WHO_REGIONS  WPR  Western Pacific Region  1980.0
# 399858  Created: 2025-02-01 16:00 UTC  NaN                     NaN     NaN
#
#         ANTIGEN                                ANTIGEN_DESCRIPTION  \
# 0           BCG                                                BCG
# 1           BCG                                                BCG
# 2       DIPHCV4  Diphtheria-containing vaccine, 4th dose (1st b...
# 3       DIPHCV4  Diphtheria-containing vaccine, 4th dose (1st b...
# 4       DIPHCV5  Diphtheria-containing vaccine, 5th dose (2nd b...
# ...         ...                                                ...
# 399854     MCV1               Measles-containing vaccine, 1st dose
# 399855      PAB  Protection at birth (PAB) against neonatal tet...
# 399856     POL3                                    Polio, 3rd dose
# 399857     RCV1               Rubella-containing vaccine, 1st dose
# 399858      NaN                                                NaN
#
#        COVERAGE_CATEGORY                      COVERAGE_CATEGORY_DESCRIPTION  \
# 0                  ADMIN                            Administrative coverage
# 1               OFFICIAL                                  Official coverage
# 2                  ADMIN                            Administrative coverage
# 3               OFFICIAL                                  Official coverage
# 4                  ADMIN                            Administrative coverage
# ...                  ...                                                ...
# 399854            WUENIC  WHO/UNICEF Estimates of National Immunization ...
# 399855               PAB                                      PAB Estimates
# 399856            WUENIC  WHO/UNICEF Estimates of National Immunization ...
# 399857            WUENIC  WHO/UNICEF Estimates of National Immunization ...
# 399858               NaN                                                NaN
#
#         TARGET_NUMBER      DOSES  COVERAGE
# 0                 NaN        NaN       NaN
# 1                 NaN        NaN       NaN
# 2              1044.0      945.0     90.52
# 3                 NaN        NaN     90.52
# 4              1219.0     1008.0     82.69
# ...               ...        ...       ...
# 399854     27939588.0  1209026.0      4.00
# 399855      4494513.0   276306.0      6.00
# 399856     27939588.0  1296611.0      5.00
# 399857     27939588.0    40245.0      0.00
# 399858            NaN        NaN       NaN
#
# [399859 rows x 11 columns]

# %%
df_coverage.isna().sum()
# Out:
# GROUP                                 0
# CODE                                  1
# NAME                               1275
# YEAR                                  1
# ANTIGEN                               1
# ANTIGEN_DESCRIPTION                   1
# COVERAGE_CATEGORY                     1
# COVERAGE_CATEGORY_DESCRIPTION         1
# TARGET_NUMBER                    320829
# DOSES                            320532
# COVERAGE                         169382
# dtype: int64

# %%
df_coverage.dropna(subset=[])
# Out:
#                                 GROUP CODE                    NAME    YEAR  \
# 0                           COUNTRIES  ABW                   Aruba  2023.0
# 1                           COUNTRIES  ABW                   Aruba  2023.0
# 2                           COUNTRIES  ABW                   Aruba  2023.0
# 3                           COUNTRIES  ABW                   Aruba  2023.0
# 4                           COUNTRIES  ABW                   Aruba  2023.0
# ...                               ...  ...                     ...     ...
# 399854                    WHO_REGIONS  WPR  Western Pacific Region  1980.0
# 399855                    WHO_REGIONS  WPR  Western Pacific Region  1980.0
# 399856                    WHO_REGIONS  WPR  Western Pacific Region  1980.0
# 399857                    WHO_REGIONS  WPR  Western Pacific Region  1980.0
# 399858  Created: 2025-02-01 16:00 UTC  NaN                     NaN     NaN
#
#         ANTIGEN                                ANTIGEN_DESCRIPTION  \
# 0           BCG                                                BCG
# 1           BCG                                                BCG
# 2       DIPHCV4  Diphtheria-containing vaccine, 4th dose (1st b...
# 3       DIPHCV4  Diphtheria-containing vaccine, 4th dose (1st b...
# 4       DIPHCV5  Diphtheria-containing vaccine, 5th dose (2nd b...
# ...         ...                                                ...
# 399854     MCV1               Measles-containing vaccine, 1st dose
# 399855      PAB  Protection at birth (PAB) against neonatal tet...
# 399856     POL3                                    Polio, 3rd dose
# 399857     RCV1               Rubella-containing vaccine, 1st dose
# 399858      NaN                                                NaN
#
#        COVERAGE_CATEGORY                      COVERAGE_CATEGORY_DESCRIPTION  \
# 0                  ADMIN                            Administrative coverage
# 1               OFFICIAL                                  Official coverage
# 2                  ADMIN                            Administrative coverage
# 3               OFFICIAL                                  Official coverage
# 4                  ADMIN                            Administrative coverage
# ...                  ...                                                ...
# 399854            WUENIC  WHO/UNICEF Estimates of National Immunization ...
# 399855               PAB                                      PAB Estimates
# 399856            WUENIC  WHO/UNICEF Estimates of National Immunization ...
# 399857            WUENIC  WHO/UNICEF Estimates of National Immunization ...
# 399858               NaN                                                NaN
#
#         TARGET_NUMBER      DOSES  COVERAGE
# 0                 NaN        NaN       NaN
# 1                 NaN        NaN       NaN
# 2              1044.0      945.0     90.52
# 3                 NaN        NaN     90.52
# 4              1219.0     1008.0     82.69
# ...               ...        ...       ...
# 399854     27939588.0  1209026.0      4.00
# 399855      4494513.0   276306.0      6.00
# 399856     27939588.0  1296611.0      5.00
# 399857     27939588.0    40245.0      0.00
# 399858            NaN        NaN       NaN
#
# [399859 rows x 11 columns]

# %%
df_coverage.dropna(subset=['CODE','YEAR','ANTIGEN','ANTIGEN_DESCRIPTION','COVERAGE_CATEGORY','COVERAGE_CATEGORY_DESCRIPTION'],inplace=True)

# %%
df_coverage['NAME'].fillna(method='bfill',inplace=True)

# %%
df_coverage.isna().sum()
# Out:
# GROUP                                 0
# CODE                                  0
# NAME                                  0
# YEAR                                  0
# ANTIGEN                               0
# ANTIGEN_DESCRIPTION                   0
# COVERAGE_CATEGORY                     0
# COVERAGE_CATEGORY_DESCRIPTION         0
# TARGET_NUMBER                    320828
# DOSES                            320531
# COVERAGE                         169381
# dtype: int64

# %%
# Check if missingness is related to specific coverage categories
missing_by_category = df_coverage.groupby('COVERAGE_CATEGORY').apply(
    lambda x: x[['TARGET_NUMBER', 'DOSES', 'COVERAGE']].isna().mean()
)

# Check if missingness is related to specific antigens
missing_by_antigen = df_coverage.groupby('ANTIGEN').apply(
    lambda x: x[['TARGET_NUMBER', 'DOSES', 'COVERAGE']].isna().mean()
)

# Check if missingness is related to specific years
missing_by_year = df_coverage.groupby('YEAR').apply(
    lambda x: x[['TARGET_NUMBER', 'DOSES', 'COVERAGE']].isna().mean()
)

# %%
missing_by_category
# Out:
#                    TARGET_NUMBER     DOSES  COVERAGE
# COVERAGE_CATEGORY
# ADMIN                   0.632668  0.630431  0.537011
# HPV                     0.741701  0.741701  0.698467
# OFFICIAL                0.999992  1.000000  0.408039
# PAB                     0.868852  0.878167  0.095194
# WUENIC                  0.846787  0.846787  0.203861

# %%
missing_by_antigen
# Out:
#               TARGET_NUMBER     DOSES  COVERAGE
# ANTIGEN
# 15HPV1_F           0.703446  0.703446  0.642112
# 15HPV1_M           0.841606  0.841606  0.820740
# 15HPVC_F           0.709453  0.709453  0.645590
# 15HPVC_M           0.842238  0.842238  0.820740
# BCG                0.784470  0.785994  0.140434
# ...                     ...       ...       ...
# TTCV6              0.851958  0.849918  0.703100
# TYPHOID            0.977759  0.976112  0.969522
# TYPHOID_CONJ       0.982982  0.979741  0.971637
# VAD1               0.901197  0.905658  0.827894
# YFV                0.892555  0.887432  0.774727
#
# [69 rows x 3 columns]

# %%
missing_by_year
# Out:
#         TARGET_NUMBER     DOSES  COVERAGE
# YEAR
# 1980.0       0.932187  0.933179  0.501489
# 1981.0       0.940614  0.941483  0.444959
# 1982.0       0.936256  0.937189  0.421953
# 1983.0       0.940837  0.941703  0.410101
# 1984.0       0.941345  0.942203  0.372532
# 1985.0       0.937583  0.938376  0.381645
# 1986.0       0.939378  0.940149  0.372207
# 1987.0       0.940808  0.941560  0.362679
# 1988.0       0.941812  0.942303  0.358949
# 1989.0       0.942167  0.942655  0.353343
# 1990.0       0.939353  0.939805  0.368183
# 1991.0       0.940259  0.940704  0.347303
# 1992.0       0.943340  0.943763  0.336575
# 1993.0       0.943804  0.944223  0.326903
# 1994.0       0.942538  0.942959  0.326879
# 1995.0       0.944456  0.944863  0.311089
# 1996.0       0.944013  0.944422  0.316919
# 1997.0       0.939196  0.939592  0.307388
# 1998.0       0.937027  0.937436  0.317113
# 1999.0       0.844345  0.846593  0.402975
# 2000.0       0.789895  0.797760  0.430743
# 2001.0       0.781734  0.787320  0.396872
# 2002.0       0.782081  0.789740  0.388728
# 2003.0       0.773524  0.782016  0.368597
# 2004.0       0.769613  0.774189  0.359310
# 2005.0       0.750331  0.751391  0.322555
# 2006.0       0.781737  0.766787  0.359163
# 2007.0       0.778127  0.763126  0.346722
# 2008.0       0.793411  0.798518  0.450831
# 2009.0       0.780773  0.785764  0.442448
# 2010.0       0.785037  0.787721  0.479577
# 2011.0       0.773253  0.779705  0.461538
# 2012.0       0.774097  0.776515  0.448582
# 2013.0       0.760522  0.764952  0.426450
# 2014.0       0.751591  0.757000  0.410595
# 2015.0       0.743145  0.746601  0.384669
# 2016.0       0.748919  0.752451  0.397203
# 2017.0       0.739133  0.740299  0.390237
# 2018.0       0.774958  0.765452  0.500341
# 2019.0       0.763853  0.754491  0.475383
# 2020.0       0.765966  0.762348  0.475159
# 2021.0       0.768103  0.764426  0.490651
# 2022.0       0.763667  0.756806  0.485207
# 2023.0       0.758256  0.752991  0.481225

# %%
# Dataset 1: Complete cases only (for precise calculations)
df_complete = df_coverage.dropna(subset=['TARGET_NUMBER', 'DOSES', 'COVERAGE'])

# Dataset 2: Coverage values available (for trend analysis)
df_coverage_available = df_coverage[df_coverage['COVERAGE'].notna()]

# Dataset 3: All data with flags for missingness (for understanding data limitations)
df_coverage['MISSING_TARGET'] = df_coverage['TARGET_NUMBER'].isna()
df_coverage['MISSING_DOSES'] = df_coverage['DOSES'].isna()
df_coverage['MISSING_COVERAGE'] = df_coverage['COVERAGE'].isna()

# %%
df_incident
# Out:
#                                GROUP CODE      NAME    YEAR          DISEASE  \
# 0                          COUNTRIES  ABW     Aruba  2023.0              CRS
# 1                          COUNTRIES  ABW     Aruba  2023.0       DIPHTHERIA
# 2                          COUNTRIES  ABW     Aruba  2023.0  INVASIVE_MENING
# 3                          COUNTRIES  ABW     Aruba  2023.0          MEASLES
# 4                          COUNTRIES  ABW     Aruba  2023.0            MUMPS
# ...                              ...  ...       ...     ...              ...
# 84941                      COUNTRIES  ZWE  Zimbabwe  1980.0        PERTUSSIS
# 84942                      COUNTRIES  ZWE  Zimbabwe  1980.0            POLIO
# 84943                      COUNTRIES  ZWE  Zimbabwe  1980.0         TTETANUS
# 84944                      COUNTRIES  ZWE  Zimbabwe  1980.0           YFEVER
# 84945  Created: 2025-02-01 16:03 UTC  NaN       NaN     NaN              NaN
#
#                   DISEASE_DESCRIPTION                     DENOMINATOR  \
# 0         Congenital rubella syndrome          per 10,000 live births
# 1                          Diphtheria  per 1,000,000 total population
# 2      Invasive meningococcal disease  per 1,000,000 total population
# 3                             Measles  per 1,000,000 total population
# 4                               Mumps  per 1,000,000 total population
# ...                               ...                             ...
# 84941                       Pertussis  per 1,000,000 total population
# 84942                   Poliomyelitis    per 1,000,000 <15 population
# 84943                   Total tetanus  per 1,000,000 total population
# 84944                    Yellow fever  per 1,000,000 total population
# 84945                             NaN                             NaN
#
#        INCIDENCE_RATE
# 0                 0.0
# 1                 0.0
# 2                 9.3
# 3                 NaN
# 4                 0.0
# ...               ...
# 84941           893.3
# 84942             NaN
# 84943            19.7
# 84944             NaN
# 84945             NaN
#
# [84946 rows x 8 columns]

# %%
df_incident.isna().sum()
# Out:
# GROUP                      0
# CODE                       1
# NAME                       1
# YEAR                       1
# DISEASE                    1
# DISEASE_DESCRIPTION        1
# DENOMINATOR                1
# INCIDENCE_RATE         23362
# dtype: int64

# %%
df_incident = df_incident.dropna(subset=['CODE','NAME','YEAR','DISEASE','DISEASE_DESCRIPTION','DENOMINATOR'])

# %%
df_incident['INCIDENCE_RATE'].fillna(0,inplace=True)
# Out:
# C:\Users\atifa\AppData\Local\Temp\ipykernel_13288\3912749310.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_incident['INCIDENCE_RATE'].fillna(0,inplace=True)

# %%
df_incident.isna().sum()
# Out:
# GROUP                  0
# CODE                   0
# NAME                   0
# YEAR                   0
# DISEASE                0
# DISEASE_DESCRIPTION    0
# DENOMINATOR            0
# INCIDENCE_RATE         0
# dtype: int64

# %%
df_reported
# Out:
#                                GROUP CODE      NAME    YEAR          DISEASE  \
# 0                          COUNTRIES  ABW     Aruba  2023.0              CRS
# 1                          COUNTRIES  ABW     Aruba  2023.0       DIPHTHERIA
# 2                          COUNTRIES  ABW     Aruba  2023.0  INVASIVE_MENING
# 3                          COUNTRIES  ABW     Aruba  2023.0          MEASLES
# 4                          COUNTRIES  ABW     Aruba  2023.0            MUMPS
# ...                              ...  ...       ...     ...              ...
# 84865                      COUNTRIES  ZWE  Zimbabwe  1980.0        PERTUSSIS
# 84866                      COUNTRIES  ZWE  Zimbabwe  1980.0            POLIO
# 84867                      COUNTRIES  ZWE  Zimbabwe  1980.0         TTETANUS
# 84868                      COUNTRIES  ZWE  Zimbabwe  1980.0           YFEVER
# 84869  Created: 2025-02-01 16:02 UTC  NaN       NaN     NaN              NaN
#
#                   DISEASE_DESCRIPTION   CASES
# 0         Congenital rubella syndrome     0.0
# 1                          Diphtheria     0.0
# 2      Invasive meningococcal disease     1.0
# 3                             Measles     NaN
# 4                               Mumps     0.0
# ...                               ...     ...
# 84865                       Pertussis  6290.0
# 84866                   Poliomyelitis    32.0
# 84867                   Total tetanus   139.0
# 84868                    Yellow fever     NaN
# 84869                             NaN     NaN
#
# [84870 rows x 7 columns]

# %%
df_reported.isna().sum()
# Out:
# GROUP                      0
# CODE                       1
# NAME                       1
# YEAR                       1
# DISEASE                    1
# DISEASE_DESCRIPTION        1
# CASES                  19400
# dtype: int64

# %%
df_reported = df_reported.dropna(subset=['CODE','NAME','YEAR','DISEASE','DISEASE_DESCRIPTION'])

# %%
df_reported['CASES'].fillna(0,inplace=True)
# Out:
# C:\Users\atifa\AppData\Local\Temp\ipykernel_13288\3895882790.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_reported['CASES'].fillna(0,inplace=True)

# %%
df_reported.isna().sum()
# Out:
# GROUP                  0
# CODE                   0
# NAME                   0
# YEAR                   0
# DISEASE                0
# DISEASE_DESCRIPTION    0
# CASES                  0
# dtype: int64

# %%
df_vac_intro
# Out:
#                            ISO_3_CODE  COUNTRYNAME WHO_REGION    YEAR  \
# 0                                 AFG  Afghanistan       EMRO  2023.0
# 1                                 AFG  Afghanistan       EMRO  2023.0
# 2                                 AFG  Afghanistan       EMRO  2023.0
# 3                                 AFG  Afghanistan       EMRO  2023.0
# 4                                 AFG  Afghanistan       EMRO  2023.0
# ...                               ...          ...        ...     ...
# 138316                            ZWE     Zimbabwe       AFRO  1943.0
# 138317                            ZWE     Zimbabwe       AFRO  1942.0
# 138318                            ZWE     Zimbabwe       AFRO  1941.0
# 138319                            ZWE     Zimbabwe       AFRO  1940.0
# 138320  Created: 2025-02-01 07:09 UTC          NaN        NaN     NaN
#
#                                         DESCRIPTION INTRO
# 0                  aP (acellular pertussis) vaccine    No
# 1                               Hepatitis A vaccine    No
# 2                               Hepatitis B vaccine   Yes
# 3                                   HepB birth dose   Yes
# 4       Hib (Haemophilus influenzae type B) vaccine   Yes
# ...                                             ...   ...
# 138316                   Seasonal Influenza vaccine    No
# 138317                   Seasonal Influenza vaccine    No
# 138318                   Seasonal Influenza vaccine    No
# 138319                   Seasonal Influenza vaccine    No
# 138320                                          NaN   NaN
#
# [138321 rows x 6 columns]

# %%
df_vac_intro.isna().sum()
# Out:
# ISO_3_CODE     0
# COUNTRYNAME    1
# WHO_REGION     1
# YEAR           1
# DESCRIPTION    1
# INTRO          1
# dtype: int64

# %%
df_vac_intro.dropna(inplace=True)

# %%
df_vac_intro.isna().sum()
# Out:
# ISO_3_CODE     0
# COUNTRYNAME    0
# WHO_REGION     0
# YEAR           0
# DESCRIPTION    0
# INTRO          0
# dtype: int64

# %%
df_vac_sched
# Out:
#                          ISO_3_CODE COUNTRYNAME WHO_REGION    YEAR  \
# 0                               ABW       Aruba       AMRO  2023.0
# 1                               ABW       Aruba       AMRO  2023.0
# 2                               ABW       Aruba       AMRO  2023.0
# 3                               ABW       Aruba       AMRO  2023.0
# 4                               ABW       Aruba       AMRO  2023.0
# ...                             ...         ...        ...     ...
# 8048                            ZWE    Zimbabwe       AFRO  2023.0
# 8049                            ZWE    Zimbabwe       AFRO  2023.0
# 8050                            ZWE    Zimbabwe       AFRO  2023.0
# 8051                            ZWE    Zimbabwe       AFRO  2023.0
# 8052  Created: 2025-02-01 16:10 UTC         NaN        NaN     NaN
#
#      VACCINECODE               VACCINE_DESCRIPTION  SCHEDULEROUNDS  TARGETPOP  \
# 0     DTAPHIBIPV  DTaP-Hib-IPV (acellular) vaccine             1.0        NaN
# 1     DTAPHIBIPV  DTaP-Hib-IPV (acellular) vaccine             2.0        NaN
# 2     DTAPHIBIPV  DTaP-Hib-IPV (acellular) vaccine             3.0        NaN
# 3     DTAPHIBIPV  DTaP-Hib-IPV (acellular) vaccine             4.0    B_2YL_W
# 4        DTAPIPV      DTaP-IPV (acellular) vaccine             5.0  B_CHILD_W
# ...          ...                               ...             ...        ...
# 8048    VITAMINA             Vitamin A supplements             3.0        NaN
# 8049    VITAMINA             Vitamin A supplements             4.0        NaN
# 8050    VITAMINA             Vitamin A supplements             5.0        NaN
# 8051    VITAMINA             Vitamin A supplements             6.0        NaN
# 8052         NaN                               NaN             NaN        NaN
#
#      TARGETPOP_DESCRIPTION   GEOAREA AGEADMINISTERED SOURCECOMMENT
# 0          General/routine  NATIONAL              M2           NaN
# 1          General/routine  NATIONAL              M4           NaN
# 2          General/routine  NATIONAL              M6           NaN
# 3          General/routine  NATIONAL             M15           NaN
# 4          General/routine  NATIONAL              Y4           NaN
# ...                    ...       ...             ...           ...
# 8048       General/routine  NATIONAL             M18        M6-M59
# 8049       General/routine  NATIONAL             M24        M6-M59
# 8050       General/routine  NATIONAL             M30        M6-M59
# 8051       General/routine  NATIONAL             M36        M6-M59
# 8052                   NaN       NaN             NaN           NaN
#
# [8053 rows x 12 columns]

# %%
df_vac_sched.isna().sum()
# Out:
# ISO_3_CODE                  0
# COUNTRYNAME                 1
# WHO_REGION                  1
# YEAR                        1
# VACCINECODE                 1
# VACCINE_DESCRIPTION         1
# SCHEDULEROUNDS              1
# TARGETPOP                4258
# TARGETPOP_DESCRIPTION       1
# GEOAREA                    31
# AGEADMINISTERED          1046
# SOURCECOMMENT            2914
# dtype: int64

# %%
df_vac_sched = df_vac_sched.dropna(subset=['COUNTRYNAME','WHO_REGION','YEAR','VACCINECODE','VACCINE_DESCRIPTION','SCHEDULEROUNDS','TARGETPOP_DESCRIPTION','GEOAREA'])

# %%
df_vac_sched.isna().sum()
# Out:
# ISO_3_CODE                  0
# COUNTRYNAME                 0
# WHO_REGION                  0
# YEAR                        0
# VACCINECODE                 0
# VACCINE_DESCRIPTION         0
# SCHEDULEROUNDS              0
# TARGETPOP                4243
# TARGETPOP_DESCRIPTION       0
# GEOAREA                     0
# AGEADMINISTERED          1034
# SOURCECOMMENT            2901
# dtype: int64

# %%
df_vac_sched.TARGETPOP.value_counts()
# Out:
# RISKGROUPS    1240
# ADULTS         656
# PW             534
# HW             327
# TRAVELLERS     207
# B_CHILD_W      164
# FEMALE         152
# B_ADO_W        130
# B_2YL_W        125
# BOTH           122
# CATCHUP_C       84
# CATCHUP_A       19
# B_ADO_F         10
# B_2YL_F          6
# B_CHILD_F        3
# Name: TARGETPOP, dtype: int64

# %%
df_vac_sched.TARGETPOP = df_vac_sched.TARGETPOP.fillna('UNKNOWN')
# Out:
# C:\Users\atifa\AppData\Local\Temp\ipykernel_13288\3501463618.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_vac_sched.TARGETPOP = df_vac_sched.TARGETPOP.fillna('UNKNOWN')

# %%
df_vac_sched.AGEADMINISTERED.value_counts()
# Out:
# M2             434
# M4             434
# 1st contact    362
# M6             344
# +M6            340
#               ...
# Y25-Y24          1
# +W8              1
# B-D5             1
# Y13-Y46          1
# Y1-Y45           1
# Name: AGEADMINISTERED, Length: 424, dtype: int64

# %%
df_vac_sched.AGEADMINISTERED = df_vac_sched.AGEADMINISTERED.fillna('UNKNOWN')
# Out:
# C:\Users\atifa\AppData\Local\Temp\ipykernel_13288\3238256345.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_vac_sched.AGEADMINISTERED = df_vac_sched.AGEADMINISTERED.fillna('UNKNOWN')

# %%
df_vac_sched.isna().sum()
# Out:
# ISO_3_CODE                  0
# COUNTRYNAME                 0
# WHO_REGION                  0
# YEAR                        0
# VACCINECODE                 0
# VACCINE_DESCRIPTION         0
# SCHEDULEROUNDS              0
# TARGETPOP                   0
# TARGETPOP_DESCRIPTION       0
# GEOAREA                     0
# AGEADMINISTERED             0
# SOURCECOMMENT            2901
# dtype: int64

# %%
import sqlite3

# Create a connection to the SQLite database
conn = sqlite3.connect('vaccination.db')

# Push each dataset to different tables in the database
df_complete.to_sql('complete_coverage', conn, if_exists='replace', index=False)
df_coverage_available.to_sql('coverage_data_available', conn, if_exists='replace', index=False)
df_coverage.to_sql('coverage_data_with_flags', conn, if_exists='replace', index=False)
df_incident.to_sql('incident_data', conn, if_exists='replace', index=False)
df_reported.to_sql('reports_data', conn, if_exists='replace', index=False)
df_vac_intro.to_sql('vaccination_introduction_data', conn, if_exists='replace', index=False)
df_vac_sched.to_sql('vaccination_scheduling', conn, if_exists='replace', index=False)
# Close the connection
conn.close()

# %%
# !pip install psycopg2-binary sqlalchemy
# Out:
# Collecting psycopg2-binary
#   Using cached psycopg2-binary-2.9.10.tar.gz (385 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: sqlalchemy in f:\anaconda\envs\tf_gpu\lib\site-packages (2.0.41)
# Requirement already satisfied: typing-extensions>=4.6.0 in f:\anaconda\envs\tf_gpu\lib\site-packages (from sqlalchemy) (4.12.2)
# Requirement already satisfied: greenlet>=1 in f:\anaconda\envs\tf_gpu\lib\site-packages (from sqlalchemy) (3.1.1)
# Building wheels for collected packages: psycopg2-binary
#   Building wheel for psycopg2-binary (setup.py): started
#   Building wheel for psycopg2-binary (setup.py): finished with status 'error'
#   Running setup.py clean for psycopg2-binary
# Failed to build psycopg2-binary
# WARNING: Ignoring invalid distribution -atplotlib (f:\anaconda\envs\tf_gpu\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (f:\anaconda\envs\tf_gpu\lib\site-packages)
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [30 lines of output]
#   running bdist_wheel
#   running build
#   running build_py
#   creating build\lib.win-amd64-cpython-38\psycopg2
#   copying lib\errorcodes.py -> build\lib.win-amd64-cpython-38\psycopg2
#   copying lib\errors.py -> build\lib.win-amd64-cpython-38\psycopg2
#   copying lib\extensions.py -> build\lib.win-amd64-cpython-38\psycopg2
#   copying lib\extras.py -> build\lib.win-amd64-cpython-38\psycopg2
#   copying lib\pool.py -> build\lib.win-amd64-cpython-38\psycopg2
#   copying lib\sql.py -> build\lib.win-amd64-cpython-38\psycopg2
#   copying lib\tz.py -> build\lib.win-amd64-cpython-38\psycopg2
#   copying lib\_ipaddress.py -> build\lib.win-amd64-cpython-38\psycopg2
#   copying lib\_json.py -> build\lib.win-amd64-cpython-38\psycopg2
#   copying lib\_range.py -> build\lib.win-amd64-cpython-38\psycopg2
#   copying lib\__init__.py -> build\lib.win-amd64-cpython-38\psycopg2
#   running build_ext
#   building 'psycopg2._psycopg' extension
#   creating build\temp.win-amd64-cpython-38\Release\psycopg
#   cl.exe /c /nologo /O2 /W3 /GL /DNDEBUG /MD "-DPSYCOPG_VERSION=2.9.10 (dt dec pq3 ext lo64)" -DPSYCOPG_DEBUG=1 -DPG_VERSION_NUM=170004 -DHAVE_LO64=1 -DPSYCOPG_DEBUG=1 -IF:\Anaconda\envs\tf_gpu\include -IF:\Anaconda\envs\tf_gpu\Include -I. -IF:/Anaconda/envs/tf_gpu/Library/include -IF:/Anaconda/envs/tf_gpu/Library/include/server "-IC:\Program Files\Microsoft Visual Studio\2022\Community\VC\Tools\MSVC\14.44.35207\include" "-IC:\Program Files\Microsoft Visual Studio\2022\Community\VC\Auxiliary\VS\include" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\ucrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\um" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\shared" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\winrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\cppwinrt" /Tcpsycopg\adapter_asis.c /Fobuild\temp.win-amd64-cpython-38\Release\psycopg\adapter_asis.obj
#
#   It appears you are missing some prerequisite to build the package from source.
#
#   You may install a binary package by installing 'psycopg2-binary' from PyPI.
#   If you want to install psycopg2 from source, please install the packages
#   required for the build and try again.
#
#   For further information please check the 'doc/src/install.rst' file (also at
#   <https://www.psycopg.org/docs/install.html>).
#
#   error: command 'cl.exe' failed: None
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for psycopg2-binary
# ERROR: Failed to build installable wheels for some pyproject.toml based projects (psycopg2-binary)

# %%
# !pip install psycopg2-binary --only-binary :all:
# Out:
# Collecting psycopg2-binary
#   Downloading psycopg2_binary-2.9.9-cp38-cp38-win_amd64.whl.metadata (4.5 kB)
# Downloading psycopg2_binary-2.9.9-cp38-cp38-win_amd64.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    --------------------------- ------------ 0.8/1.2 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------------- 1.2/1.2 MB 4.8 MB/s eta 0:00:00
# Installing collected packages: psycopg2-binary
# Successfully installed psycopg2-binary-2.9.9
# WARNING: Ignoring invalid distribution -atplotlib (f:\anaconda\envs\tf_gpu\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (f:\anaconda\envs\tf_gpu\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (f:\anaconda\envs\tf_gpu\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (f:\anaconda\envs\tf_gpu\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (f:\anaconda\envs\tf_gpu\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (f:\anaconda\envs\tf_gpu\lib\site-packages)

# %%
from sqlalchemy import create_engine

# Define database connections
sqlite_conn = sqlite3.connect('vaccination.db')
postgres_engine = create_engine('postgresql://postgres:root@localhost:5432/vaccination')

# List of tables to migrate
tables = [
    'complete_coverage',
    'coverage_data_available', 
    'coverage_data_with_flags',
    'incident_data',
    'reports_data',
    'vaccination_introduction_data',
    'vaccination_scheduling'
]

# Migrate each table
for table in tables:
    try:
        # Read from SQLite
        df = pd.read_sql_query(f"SELECT * FROM {table}", sqlite_conn)
        
        # Write to PostgreSQL
        df.to_sql(table, postgres_engine, if_exists='replace', index=False, method='multi')
        
        print(f"Successfully migrated {table} with {len(df)} rows")
        
    except Exception as e:
        print(f"Error migrating {table}: {str(e)}")

# Close connections
sqlite_conn.close()
postgres_engine.dispose()

print("Migration completed!")
# Out:
# Successfully migrated complete_coverage with 76473 rows
# Successfully migrated coverage_data_available with 230477 rows
# Successfully migrated coverage_data_with_flags with 399858 rows
# Successfully migrated incident_data with 84945 rows
# Successfully migrated reports_data with 84869 rows
# Successfully migrated vaccination_introduction_data with 138320 rows
# Successfully migrated vaccination_scheduling with 8022 rows
# Migration completed!

# %%
df_vac_intro[(df_vac_intro['DESCRIPTION'] == 'IPV (Inactivated polio vaccine)') & ((df_vac_intro['INTRO'] == 'Yes') | (df_vac_intro['INTRO'] == 'Yes (P)'))]
# Out:
#        ISO_3_CODE  COUNTRYNAME WHO_REGION    YEAR  \
# 6             AFG  Afghanistan       EMRO  2023.0
# 27            AFG  Afghanistan       EMRO  2022.0
# 48            AFG  Afghanistan       EMRO  2021.0
# 69            AFG  Afghanistan       EMRO  2020.0
# 90            AFG  Afghanistan       EMRO  2019.0
# ...           ...          ...        ...     ...
# 137579        ZWE     Zimbabwe       AFRO  2023.0
# 137600        ZWE     Zimbabwe       AFRO  2022.0
# 137621        ZWE     Zimbabwe       AFRO  2021.0
# 137642        ZWE     Zimbabwe       AFRO  2020.0
# 137663        ZWE     Zimbabwe       AFRO  2019.0
#
#                             DESCRIPTION INTRO
# 6       IPV (Inactivated polio vaccine)   Yes
# 27      IPV (Inactivated polio vaccine)   Yes
# 48      IPV (Inactivated polio vaccine)   Yes
# 69      IPV (Inactivated polio vaccine)   Yes
# 90      IPV (Inactivated polio vaccine)   Yes
# ...                                 ...   ...
# 137579  IPV (Inactivated polio vaccine)   Yes
# 137600  IPV (Inactivated polio vaccine)   Yes
# 137621  IPV (Inactivated polio vaccine)   Yes
# 137642  IPV (Inactivated polio vaccine)   Yes
# 137663  IPV (Inactivated polio vaccine)   Yes
#
# [3078 rows x 6 columns]

# %%
df_
